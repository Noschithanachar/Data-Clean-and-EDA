# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
import seaborn as sns

# %%
data = pd.read_csv("D:\\EDA\\eda\\rawdata\\LARPDatabase_2015.csv")

# %%
data
# Out:
#        Unnamed: 0        MANAGEMENT          VESSEL             REF NO  \
# 0               0    SMPL - Chennai    NANYANG STAR    LR/NAST/2018/98
# 1               1    SMPL - Chennai      DEE4 BIRCH   LR/FRHA/2018/152
# 2               2    SMPL - Chennai    NANYANG STAR   LR/NAST/2018/153
# 3               3    SMPL - Chennai  VELOS SAPPHIRE  LR/GRVIC/2015/106
# 4               4  SMSL - Singapore         BENFICA     LR/BNFC/2018/3
# ...           ...               ...             ...                ...
# 61045       61068  SMSL - Singapore    BULK HOLLAND   LR/BUHD/2018/126
# 61046       61069    SMPL - Chennai      GAS STELLA    LR/STGS/2018/81
# 61047       61070    SMPL - Chennai     APL FLORIDA    LR/AFLO/2019/85
# 61048       61071    SMPL - Chennai      DEE4 CEDAR   LR/ORST/2018/283
# 61049       61072    SMPL - Chennai         CASTARA    LR/CAST/2019/47
#
#                OCCURRENCE DATE    STATUS  \
# 0      2018-04-22 03:05:14.000  Accepted
# ...

# %%
data.isna().sum()
# Out:
# Unnamed: 0                    0
# MANAGEMENT                  966
# VESSEL                      966
# REF NO                        0
# OCCURRENCE DATE               0
# STATUS                        0
# AREA OF CONCERN           21144
# DESCRIPTION                  17
# IMMEDIATE ACTION TAKEN     7756
# CATEGORY                      0
# WORK EQUIPMENT            54445
# LARP PROCEDURE            34363
# LARP SAFETY DEVICE        54339
# WORK ENVIRONMENT          56635
# HOUSE KEEPING             54574
# PERMIT TO WORK            60379
# LARP PPE                  52753
# WORK POSITION             53365
# REPORTED BY                8957
# CLOSURE REMARK            55449
# CLOSURE DATE              55443
# CLOSED BY                 55444
# dtype: int64

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'MANAGEMENT', 'VESSEL', 'REF NO', 'OCCURRENCE DATE',
#        'STATUS', 'AREA OF CONCERN', 'DESCRIPTION', 'IMMEDIATE ACTION TAKEN',
#        'CATEGORY', 'WORK EQUIPMENT', 'LARP PROCEDURE', 'LARP SAFETY DEVICE',
#        'WORK ENVIRONMENT', 'HOUSE KEEPING', 'PERMIT TO WORK', 'LARP PPE',
#        'WORK POSITION', 'REPORTED BY', 'CLOSURE REMARK', 'CLOSURE DATE',
#        'CLOSED BY'],
#       dtype='str')

# %%
data['Unnamed: 0'].isna().sum()
# Out:
# np.int64(0)

# %%
data = data.drop(columns=['Unnamed: 0'])

# %%
data.columns
# Out:
# Index(['MANAGEMENT', 'VESSEL', 'REF NO', 'OCCURRENCE DATE', 'STATUS',
#        'AREA OF CONCERN', 'DESCRIPTION', 'IMMEDIATE ACTION TAKEN', 'CATEGORY',
#        'WORK EQUIPMENT', 'LARP PROCEDURE', 'LARP SAFETY DEVICE',
#        'WORK ENVIRONMENT', 'HOUSE KEEPING', 'PERMIT TO WORK', 'LARP PPE',
#        'WORK POSITION', 'REPORTED BY', 'CLOSURE REMARK', 'CLOSURE DATE',
#        'CLOSED BY'],
#       dtype='str')

# %%
data['MANAGEMENT'].value_counts()
# Out:
# MANAGEMENT
# SMPL - Chennai      42367
# SMSL - Singapore     9069
# SNSPL - Pune         5029
# SOS - Kochi          3619
# Name: count, dtype: int64

# %%
data['VESSEL']
# Out:
# 0          NANYANG STAR
# 1            DEE4 BIRCH
# 2          NANYANG STAR
# 3        VELOS SAPPHIRE
# 4               BENFICA
#               ...
# 61045      BULK HOLLAND
# 61046        GAS STELLA
# 61047       APL FLORIDA
# 61048        DEE4 CEDAR
# 61049           CASTARA
# Name: VESSEL, Length: 61050, dtype: str

# %%
data['REF NO'].value_counts()
# Out:
# REF NO
# LR/NAST/2018/98      1
# LR/FRHA/2018/152     1
# LR/NAST/2018/153     1
# LR/GRVIC/2015/106    1
# LR/BNFC/2018/3       1
#                     ..
# LR/BUHD/2018/126     1
# LR/STGS/2018/81      1
# LR/AFLO/2019/85      1
# LR/ORST/2018/283     1
# LR/CAST/2019/47      1
# Name: count, Length: 61050, dtype: int64

# %%
data.columns
# Out:
# Index(['MANAGEMENT', 'VESSEL', 'REF NO', 'OCCURRENCE DATE', 'STATUS',
#        'AREA OF CONCERN', 'DESCRIPTION', 'IMMEDIATE ACTION TAKEN', 'CATEGORY',
#        'WORK EQUIPMENT', 'LARP PROCEDURE', 'LARP SAFETY DEVICE',
#        'WORK ENVIRONMENT', 'HOUSE KEEPING', 'PERMIT TO WORK', 'LARP PPE',
#        'WORK POSITION', 'REPORTED BY', 'CLOSURE REMARK', 'CLOSURE DATE',
#        'CLOSED BY'],
#       dtype='str')

# %%
data['OCCURRENCE DATE']
# Out:
# 0        2018-04-22 03:05:14.000
# 1        2018-08-18 09:21:47.000
# 2        2018-05-20 08:35:46.000
# 3        2015-12-07 09:54:27.000
# 4        2018-01-16 10:45:21.000
#                   ...
# 61045    2018-12-28 13:50:04.000
# 61046    2018-09-11 21:35:08.000
# 61047    2019-08-13 04:03:58.000
# 61048    2018-10-14 06:57:36.000
# 61049    2019-04-20 15:06:19.000
# Name: OCCURRENCE DATE, Length: 61050, dtype: str

# %%
data['OCCURRENCE DATE'] = pd.to_datetime(data['OCCURRENCE DATE'])
data['OCCURRENCE DATE'] = data['OCCURRENCE DATE'].dt.strftime('%Y-%m-%d %H:%M:%S')

# %%
data['OCCURRENCE DATE']
# Out:
# 0        2018-04-22 03:05:14
# 1        2018-08-18 09:21:47
# 2        2018-05-20 08:35:46
# 3        2015-12-07 09:54:27
# 4        2018-01-16 10:45:21
#                 ...
# 61045    2018-12-28 13:50:04
# 61046    2018-09-11 21:35:08
# 61047    2019-08-13 04:03:58
# 61048    2018-10-14 06:57:36
# 61049    2019-04-20 15:06:19
# Name: OCCURRENCE DATE, Length: 61050, dtype: str

# %%
data.columns
# Out:
# Index(['MANAGEMENT', 'VESSEL', 'REF NO', 'OCCURRENCE DATE', 'STATUS',
#        'AREA OF CONCERN', 'DESCRIPTION', 'IMMEDIATE ACTION TAKEN', 'CATEGORY',
#        'WORK EQUIPMENT', 'LARP PROCEDURE', 'LARP SAFETY DEVICE',
#        'WORK ENVIRONMENT', 'HOUSE KEEPING', 'PERMIT TO WORK', 'LARP PPE',
#        'WORK POSITION', 'REPORTED BY', 'CLOSURE REMARK', 'CLOSURE DATE',
#        'CLOSED BY'],
#       dtype='str')

# %%
data['STATUS'].value_counts()
# Out:
# STATUS
# Accepted    57159
# Open         3521
# Rejected      370
# Name: count, dtype: int64

# %%
data['AREA OF CONCERN'].value_counts()
# Out:
# AREA OF CONCERN
# Safety Management (LSA & FFA) and security - Ch 5 d. COWSP                                      9587
# Ch V/Safety Management- (Reporting- LARP, Near Misses, Incident Investigations and PSC etc.)    3210
# Ch I GENERAL INFORMATION                                                                        2186
# General Appearance and condition - Ch 12                                                        2074
# Ch V/Safety Management- (Safe Access)                                                           1546
#                                                                                                 ...
# Ch VIII/ Cargo & Ballast System- (Cargo compressor and Motor Room)-LPG                             3
# Ch VIII/ Cargo & Ballast System- (Crude oil washing)                                               3
# Ch VIII/ Cargo & Ballast System- (Pressure relief and venting system)-LPG                          2
# ...

# %%
data.columns
# Out:
# Index(['MANAGEMENT', 'VESSEL', 'REF NO', 'OCCURRENCE DATE', 'STATUS',
#        'AREA OF CONCERN', 'DESCRIPTION', 'IMMEDIATE ACTION TAKEN', 'CATEGORY',
#        'WORK EQUIPMENT', 'LARP PROCEDURE', 'LARP SAFETY DEVICE',
#        'WORK ENVIRONMENT', 'HOUSE KEEPING', 'PERMIT TO WORK', 'LARP PPE',
#        'WORK POSITION', 'REPORTED BY', 'CLOSURE REMARK', 'CLOSURE DATE',
#        'CLOSED BY'],
#       dtype='str')

# %%
data['DESCRIPTION'].isna().sum()
# Out:
# np.int64(17)

# %%
data.columns
# Out:
# Index(['MANAGEMENT', 'VESSEL', 'REF NO', 'OCCURRENCE DATE', 'STATUS',
#        'AREA OF CONCERN', 'DESCRIPTION', 'IMMEDIATE ACTION TAKEN', 'CATEGORY',
#        'WORK EQUIPMENT', 'LARP PROCEDURE', 'LARP SAFETY DEVICE',
#        'WORK ENVIRONMENT', 'HOUSE KEEPING', 'PERMIT TO WORK', 'LARP PPE',
#        'WORK POSITION', 'REPORTED BY', 'CLOSURE REMARK', 'CLOSURE DATE',
#        'CLOSED BY'],
#       dtype='str')

# %%
data['IMMEDIATE ACTION TAKEN'].value_counts()
# Out:
# IMMEDIATE ACTION TAKEN
# 1                                                                                                                                                                 960
# Stopped and consequences discussed.                                                                                                                                48
# stopped and consequences discussed.                                                                                                                                46
# appreciated                                                                                                                                                        15
# STOPPED AND CONSEQUENCES DISCUSSED.                                                                                                                                14
# ...

# %%
data['CATEGORY'].value_counts()
# Out:
# CATEGORY
# Unsafe act    48465
# Safe act      12585
# Name: count, dtype: int64

# %%
data.columns
# Out:
# Index(['MANAGEMENT', 'VESSEL', 'REF NO', 'OCCURRENCE DATE', 'STATUS',
#        'AREA OF CONCERN', 'DESCRIPTION', 'IMMEDIATE ACTION TAKEN', 'CATEGORY',
#        'WORK EQUIPMENT', 'LARP PROCEDURE', 'LARP SAFETY DEVICE',
#        'WORK ENVIRONMENT', 'HOUSE KEEPING', 'PERMIT TO WORK', 'LARP PPE',
#        'WORK POSITION', 'REPORTED BY', 'CLOSURE REMARK', 'CLOSURE DATE',
#        'CLOSED BY'],
#       dtype='str')

# %%
data['WORK EQUIPMENT'].isna().sum()
# Out:
# np.int64(54445)

# %%
data.drop(columns=['WORK EQUIPMENT'], inplace=True)

# %%
data.columns
# Out:
# Index(['MANAGEMENT', 'VESSEL', 'REF NO', 'OCCURRENCE DATE', 'STATUS',
#        'AREA OF CONCERN', 'DESCRIPTION', 'IMMEDIATE ACTION TAKEN', 'CATEGORY',
#        'LARP PROCEDURE', 'LARP SAFETY DEVICE', 'WORK ENVIRONMENT',
#        'HOUSE KEEPING', 'PERMIT TO WORK', 'LARP PPE', 'WORK POSITION',
#        'REPORTED BY', 'CLOSURE REMARK', 'CLOSURE DATE', 'CLOSED BY'],
#       dtype='str')

# %%
data['LARP PROCEDURE']
# Out:
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3        Not followed
# 4                 NaN
#              ...
# 61045       Not aware
# 61046    Not followed
# 61047    Not followed
# 61048    Not followed
# 61049    Not followed
# Name: LARP PROCEDURE, Length: 61050, dtype: str

# %%
data['LARP SAFETY DEVICE'].isna().sum()
# Out:
# np.int64(54339)

# %%
data.drop(columns = ['LARP SAFETY DEVICE'], inplace=True)

# %%
data.columns
# Out:
# Index(['MANAGEMENT', 'VESSEL', 'REF NO', 'OCCURRENCE DATE', 'STATUS',
#        'AREA OF CONCERN', 'DESCRIPTION', 'IMMEDIATE ACTION TAKEN', 'CATEGORY',
#        'LARP PROCEDURE', 'WORK ENVIRONMENT', 'HOUSE KEEPING', 'PERMIT TO WORK',
#        'LARP PPE', 'WORK POSITION', 'REPORTED BY', 'CLOSURE REMARK',
#        'CLOSURE DATE', 'CLOSED BY'],
#       dtype='str')

# %%
data
# Out:
#              MANAGEMENT          VESSEL             REF NO  \
# 0        SMPL - Chennai    NANYANG STAR    LR/NAST/2018/98
# 1        SMPL - Chennai      DEE4 BIRCH   LR/FRHA/2018/152
# 2        SMPL - Chennai    NANYANG STAR   LR/NAST/2018/153
# 3        SMPL - Chennai  VELOS SAPPHIRE  LR/GRVIC/2015/106
# 4      SMSL - Singapore         BENFICA     LR/BNFC/2018/3
# ...                 ...             ...                ...
# 61045  SMSL - Singapore    BULK HOLLAND   LR/BUHD/2018/126
# 61046    SMPL - Chennai      GAS STELLA    LR/STGS/2018/81
# 61047    SMPL - Chennai     APL FLORIDA    LR/AFLO/2019/85
# 61048    SMPL - Chennai      DEE4 CEDAR   LR/ORST/2018/283
# 61049    SMPL - Chennai         CASTARA    LR/CAST/2019/47
#
#            OCCURRENCE DATE    STATUS  \
# 0      2018-04-22 03:05:14  Accepted
# 1      2018-08-18 09:21:47  Accepted
# 2      2018-05-20 08:35:46  Accepted
# 3      2015-12-07 09:54:27  Accepted
# 4      2018-01-16 10:45:21  Accepted
# ...

# %%
data.columns
# Out:
# Index(['MANAGEMENT', 'VESSEL', 'REF NO', 'OCCURRENCE DATE', 'STATUS',
#        'AREA OF CONCERN', 'DESCRIPTION', 'IMMEDIATE ACTION TAKEN', 'CATEGORY',
#        'LARP PROCEDURE', 'WORK ENVIRONMENT', 'HOUSE KEEPING', 'PERMIT TO WORK',
#        'LARP PPE', 'WORK POSITION', 'REPORTED BY', 'CLOSURE REMARK',
#        'CLOSURE DATE', 'CLOSED BY'],
#       dtype='str')

# %%
data['HOUSE KEEPING'].isna().sum()
# Out:
# np.int64(54574)

# %%
data.drop(columns=['HOUSE KEEPING'], inplace=True)

# %%
data.columns
# Out:
# Index(['MANAGEMENT', 'VESSEL', 'REF NO', 'OCCURRENCE DATE', 'STATUS',
#        'AREA OF CONCERN', 'DESCRIPTION', 'IMMEDIATE ACTION TAKEN', 'CATEGORY',
#        'LARP PROCEDURE', 'WORK ENVIRONMENT', 'PERMIT TO WORK', 'LARP PPE',
#        'WORK POSITION', 'REPORTED BY', 'CLOSURE REMARK', 'CLOSURE DATE',
#        'CLOSED BY'],
#       dtype='str')

# %%
data['PERMIT TO WORK'].isna().sum()
# Out:
# np.int64(60379)

# %%
data.drop(columns=['PERMIT TO WORK'], inplace=True)

# %%
data.columns
# Out:
# Index(['MANAGEMENT', 'VESSEL', 'REF NO', 'OCCURRENCE DATE', 'STATUS',
#        'AREA OF CONCERN', 'DESCRIPTION', 'IMMEDIATE ACTION TAKEN', 'CATEGORY',
#        'LARP PROCEDURE', 'WORK ENVIRONMENT', 'LARP PPE', 'WORK POSITION',
#        'REPORTED BY', 'CLOSURE REMARK', 'CLOSURE DATE', 'CLOSED BY'],
#       dtype='str')

# %%
data['WORK POSITION'].isna().sum()
# Out:
# np.int64(53365)

# %%
data['WORK POSITION'].value_counts()
# Out:
# WORK POSITION
# Falling                          3759
# Near dust/Hazardous substance    1353
# Object Falling                    754
# Near source of electricity        622
# Near extreme temperature          574
# Lifting                           513
# Fatigue                           110
# Name: count, dtype: int64

# %%
data['REPORTED BY'].value_counts()
# Out:
# REPORTED BY
# Neil Perez Galvadores             283
# Amit Kumar                        136
# Sumit Kumar                       128
# Abhishek Kumar                    121
# Cyril Angelo Pimentel Patricio    117
#                                  ...
# Mohan Ram Khilery                   1
# Santosh Kumar Singh                 1
# Hemant Namdev Mandvikar             1
# Vignesh Sanjeev                     1
# Tomas Leslie Catarina Pereira       1
# Name: count, Length: 6871, dtype: int64

# %%
data['CLOSURE REMARK'].value_counts()
# Out:
# CLOSURE REMARK
# To be reviewed and discussed in next safety meeting.                                                                            1631
# To review and discuss in next Safety meeting.                                                                                    411
# To be review in next Safety Meeting. Kindly discuss in next safety Meeting                                                       274
# To review and discuss in next Safety Meeting.                                                                                    271
# To be reviewed and discussed in next safety meeting                                                                              232
#                                                                                                                                 ...
# master to advice all crew member not to use the cell phone during watch                                                            1
# ...

# %%
data.columns
# Out:
# Index(['MANAGEMENT', 'VESSEL', 'REF NO', 'OCCURRENCE DATE', 'STATUS',
#        'AREA OF CONCERN', 'DESCRIPTION', 'IMMEDIATE ACTION TAKEN', 'CATEGORY',
#        'LARP PROCEDURE', 'WORK ENVIRONMENT', 'LARP PPE', 'WORK POSITION',
#        'REPORTED BY', 'CLOSURE REMARK', 'CLOSURE DATE', 'CLOSED BY'],
#       dtype='str')

# %%
data['CLOSURE DATE'].isna().sum()
# Out:
# np.int64(55443)

# %%
data['CLOSURE DATE'].value_counts()
# Out:
# CLOSURE DATE
# 2015-10-01 10:11:02.063    1
# 2017-12-05 11:31:47.177    1
# 2018-01-02 10:11:23.000    1
# 2018-02-04 19:45:01.747    1
# 2019-01-04 16:13:39.047    1
#                           ..
# 2019-06-07 14:54:22.500    1
# 2019-12-12 14:15:27.550    1
# 2019-11-12 15:38:24.737    1
# 2018-11-29 16:33:30.740    1
# 2019-03-18 17:50:25.697    1
# Name: count, Length: 5607, dtype: int64

# %%
data['CLOSED BY'].isna().sum()
# Out:
# np.int64(55444)

# %%
data.shape
data.info()
data.isnull().sum()
data.duplicated().sum()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 61050 entries, 0 to 61049
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   MANAGEMENT              60084 non-null  str
#  1   VESSEL                  60084 non-null  str
#  2   REF NO                  61050 non-null  str
#  3   OCCURRENCE DATE         61050 non-null  str
#  4   STATUS                  61050 non-null  str
#  5   AREA OF CONCERN         39906 non-null  str
#  6   DESCRIPTION             61033 non-null  str
#  7   IMMEDIATE ACTION TAKEN  53294 non-null  str
#  8   CATEGORY                61050 non-null  str
#  9   LARP PROCEDURE          26687 non-null  str
#  10  WORK ENVIRONMENT        4415 non-null   str
#  11  LARP PPE                8297 non-null   str
#  12  WORK POSITION           7685 non-null   str
#  13  REPORTED BY             52093 non-null  str
#  14  CLOSURE REMARK          5601 non-null   str
# ...

# %%
data["OCCURRENCE DATE"] = pd.to_datetime(data["OCCURRENCE DATE"], errors="coerce")
data["CLOSURE DATE"] = pd.to_datetime(data["CLOSURE DATE"], errors="coerce")

# %%
data["VESSEL"].value_counts().head(10)
# Out:
# VESSEL
# BENFICA           1142
# APL ANTWERP       1115
# SEROJA ENAM        885
# DEE4 CEDAR         884
# APL OREGON         884
# MOL PRESENCE       863
# SEROJA EMPAT       796
# NINGBO DAWN        762
# APL CALIFORNIA     709
# DALI               704
# Name: count, dtype: int64

# %%
data["CATEGORY"].value_counts()
# Out:
# CATEGORY
# Unsafe act    48465
# Safe act      12585
# Name: count, dtype: int64

# %%
data["AREA OF CONCERN"].value_counts()
# Out:
# AREA OF CONCERN
# Safety Management (LSA & FFA) and security - Ch 5 d. COWSP                                      9587
# Ch V/Safety Management- (Reporting- LARP, Near Misses, Incident Investigations and PSC etc.)    3210
# Ch I GENERAL INFORMATION                                                                        2186
# General Appearance and condition - Ch 12                                                        2074
# Ch V/Safety Management- (Safe Access)                                                           1546
#                                                                                                 ...
# Ch VIII/ Cargo & Ballast System- (Cargo compressor and Motor Room)-LPG                             3
# Ch VIII/ Cargo & Ballast System- (Crude oil washing)                                               3
# Ch VIII/ Cargo & Ballast System- (Pressure relief and venting system)-LPG                          2
# ...

# %%
data["year"] = data["OCCURRENCE DATE"].dt.year

data["year"].value_counts().sort_index()
# Out:
# year
# 2015     3222
# 2016     6996
# 2017    11155
# 2018    16759
# 2019    22918
# Name: count, dtype: int64

# %%
data.groupby(data["OCCURRENCE DATE"].dt.year).size()
# Out:
# OCCURRENCE DATE
# 2015     3222
# 2016     6996
# 2017    11155
# 2018    16759
# 2019    22918
# dtype: int64

# %%
data.groupby(data["OCCURRENCE DATE"].dt.year).size().plot()
# Out:
# <Axes: xlabel='OCCURRENCE DATE'>

# %%
data["closure_days"] = (
    data["CLOSURE DATE"] - data["OCCURRENCE DATE"]
).dt.days

# %%
data["closure_days"].describe()
# Out:
# count    5607.000000
# mean       68.003567
# std       101.480487
# min         0.000000
# 25%        21.000000
# 50%        48.000000
# 75%        81.000000
# max       916.000000
# Name: closure_days, dtype: float64

# %%
pd.crosstab(data["CATEGORY"], data["AREA OF CONCERN"])
# Out:
# AREA OF CONCERN  Cargo and ballast system - Ch 8 a. Plan  \
# CATEGORY
# Safe act                                              21
# Unsafe act                                            49
#
# AREA OF CONCERN  Cargo and ballast system - Ch 8 b. Execution  \
# CATEGORY
# Safe act                                                   53
# Unsafe act                                                202
#
# AREA OF CONCERN  Cargo and ballast system - Ch 8 c. Monitoring  \
# CATEGORY
# Safe act                                                   101
# Unsafe act                                                 452
#
# AREA OF CONCERN  Certification (National, International and class) - Ch 2  \
# CATEGORY
# Safe act                                                         0
# Unsafe act                                                      10
#
# AREA OF CONCERN  Ch I GENERAL INFORMATION  \
# CATEGORY
# Safe act                              431
# Unsafe act                           1755
#
# ...

# %%
from collections import Counter

words = " ".join(data["DESCRIPTION"].dropna()).split()

Counter(words).most_common(20)
# Out:
# [('the', 46977),
#  ('of', 23502),
#  ('was', 21862),
#  ('crew', 18746),
#  ('to', 17388),
#  ('in', 16850),
#  ('and', 16627),
#  ('found', 15828),
#  ('on', 13785),
#  ('not', 10739),
#  ('member', 10574),
#  ('one', 9304),
#  ('THE', 8218),
#  ('while', 7472),
#  ('without', 7123),
#  ('for', 7014),
#  ('with', 6971),
#  ('Found', 6415),
#  ('deck', 6410),
#  ('During', 6397)]

# %%
data["STATUS"].value_counts(normalize=True)
# Out:
# STATUS
# Accepted    0.936265
# Open        0.057674
# Rejected    0.006061
# Name: proportion, dtype: float64

# %%
data.groupby("VESSEL").size().sort_values(ascending=False)
# Out:
# VESSEL
# BENFICA          1142
# APL ANTWERP      1115
# SEROJA ENAM       885
# DEE4 CEDAR        884
# APL OREGON        884
#                  ...
# NORD NEPTUNE        3
# NORD QUEBEC         2
# EHIME QUEEN         2
# PACIFIC SOUTH       2
# WESTMINSTER         1
# Length: 274, dtype: int64

# %%
data.groupby("MANAGEMENT").size()
# Out:
# MANAGEMENT
# SMPL - Chennai      42367
# SMSL - Singapore     9069
# SNSPL - Pune         5029
# SOS - Kochi          3619
# dtype: int64

# %%
import seaborn as sns

table = pd.crosstab(data["CATEGORY"], data["AREA OF CONCERN"])

sns.heatmap(table)
# Out:
# <Axes: xlabel='AREA OF CONCERN', ylabel='CATEGORY'>

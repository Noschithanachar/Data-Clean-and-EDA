# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("D:/EDA/eda/rawdata/NMDatabase.csv")

# %%
data
# Out:
#           NME ID             Ref.No.    Name of Ship Type of Ship  \
# 0      NME100000         CAL-01/2012  APL CALIFORNIA    CONTAINER
# 1      NME100001         CHI-01/2012        TS CHINA    CONTAINER
# 2      NME100002         CHI-02/2012        TS CHINA    CONTAINER
# 3      NME100003         FLD-01-2012     APL FLORIDA    CONTAINER
# 4      NME100004          CAP-001/12   CALA PINGUINO    CONTAINER
# ...          ...                 ...             ...          ...
# 12441  NME112441  NM/NBAL/2020/Apr/4     NORD BALTIC          NAN
# 12442  NME112442  NM/NSFX/2020/Apr/6    NAVIOS FELIX          NAN
# 12443  NME112443  NM/VOLN/2020/Apr/7         VOLANTE          NAN
# 12444  NME112444  NM/HOUM/2020/Apr/8     HOURAI MARU          NAN
# 12445  NME112445  NM/LORD/2020/May/3         BW LORD          NAN
#
#                 Date of Report  Delay (in days)  \
# 0                   2012-01-03              0.0
# 1                   2012-01-05              0.0
# 2                   2012-01-06              0.0
# 3                   2012-01-09              2.0
# 4                   2012-01-23             16.0
# ...                        ...              ...
# 12441  2020-04-12 17:43:37.050              NaN
# 12442  2020-04-21 06:22:51.907              NaN
# 12443  2020-04-30 12:20:24.683              NaN
# 12444  2020-04-24 13:43:40.970              NaN
# 12445  2020-05-02 17:40:18.397              NaN
#
#           Description of the incident and cause analysis        Location  \
# 0      On 03 Jan 2012 @ 0254 hrs vessel berthed at qi...          Galley
# 1      The ship departed port of osaka ,and main engi...  Machinery Room
# 2      While the Ship was in Port ( NAGOYA - JAPAN ) ...  Machinery Room
# 3      Vessel approaching berth at Yokohama,Japan wit...          Bridge
# 4      AFT TUG LINE PARTED WHILE DEPARTING PUERTO CAB...    Mooring Area
# ...                                                  ...             ...
# 12441  Stevedores about to transfer shore escavator u...             Sea
# 12442  During Safety around checked, 4/E was focussin...             Sea
# 12443  During routine round of the engine room it was...             Sea
# 12444  While casting off the tug at aft station the t...            Port
# 12445  High pressure hydroblasting hose ruptured and ...             Sea
#
#       Probability of Reoccurence  \
# 0                         Likely
# 1                       Very Low
# 2                       Very Low
# 3                       Very Low
# 4                    Very Likely
# ...                          ...
# 12441                     Likely
# 12442                   Unlikely
# 12443                     Likely
# 12444                   Unlikely
# 12445                Very Likely
#
#                                           Cause Analysis  ... IndirectCause  \
# 0      Suspect undeclared machinery stowed inside a c...  ...           NaN
# 1      Failure to follow repair / maintenance instruc...  ...           NaN
# 2      Failure to follow repair/maintenance instructi...  ...           NaN
# 3      Prior arrival to Yokohama, vessel had very bad...  ...           NaN
# 4      Duty Officer should always check the quality o...  ...           NaN
# ...                                                  ...  ...           ...
# 12441                                                NaN  ...           NaN
# 12442                                                NaN  ...           NaN
# 12443                                                NaN  ...           NaN
# 12444                                                NaN  ...           NaN
# 12445                                                NaN  ...           NaN
#
#       RootCause RevisedIncidentCategory LessionLearnt ReviewComments  \
# 0           NaN                     NaN           NaN            NaN
# 1           NaN                     NaN           NaN            NaN
# 2           NaN                     NaN           NaN            NaN
# 3           NaN                     NaN           NaN            NaN
# 4           NaN                     NaN           NaN            NaN
# ...         ...                     ...           ...            ...
# 12441       NaN                     NaN           NaN            NaN
# 12442       NaN                     NaN           NaN            NaN
# 12443       NaN                     NaN           NaN            NaN
# 12444       NaN                     NaN           NaN            NaN
# 12445       NaN                     NaN           NaN            NaN
#
#                                              ClosingNote          ClosingDate  \
# 0                                                    NaN                  NaN
# 1                                                    NaN                  NaN
# 2                                                    NaN                  NaN
# 3                                                    NaN                  NaN
# 4                                                    NaN                  NaN
# ...                                                  ...                  ...
# 12441  Thank you for being vigilant and devoting time...  2020-04-29 00:00:00
# 12442                                                NaN                  NaN
# 12443                                                NaN                  NaN
# 12444                         UNSAFE CONDITION.NM Closed  2020-05-11 00:00:00
# 12445  High pressure hoses shall be checked thoroughl...  2020-06-01 00:00:00
#
#       Incident_Category_Potential   Probability_of_Reoccurence  \
# 0        Marginal-Moderate-Medium  Likely-High-Medium-Moderate
# 1                 Critical-Severe       Very Unlikely-Very Low
# 2        Marginal-Moderate-Medium       Very Unlikely-Very Low
# 3                Minor-Low-Slight       Very Unlikely-Very Low
# 4                Minor-Low-Slight        Very Likely-Very High
# ...                           ...                          ...
# 12441    Marginal-Moderate-Medium  Likely-High-Medium-Moderate
# 12442  Catastrophic-Major-Extreme        Unlikely-Low-Marginal
# 12443            Minor-Low-Slight  Likely-High-Medium-Moderate
# 12444            Minor-Low-Slight        Unlikely-Low-Marginal
# 12445    Marginal-Moderate-Medium        Very Likely-Very High
#
#       Port Country Name
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 12441               NaN
# 12442               NaN
# 12443               NaN
# 12444               NaN
# 12445               NaN
#
# [12446 rows x 57 columns]

# %%
data.columns
# Out:
# Index(['NME ID', 'Ref.No.', 'Name of Ship', 'Type of Ship', 'Date of Report',
#        'Delay (in days)', 'Description of the incident and cause analysis',
#        'Location', 'Probability of Reoccurence', 'Cause Analysis',
#        'Counter measure to prevent recurrence',
#        'Suggested Corrective Action (Office Use)',
#        'Date Corrective action completed', 'Area of Concern',
#        'Date Investigation Commenced', 'Target Date',
#        'Date of Investigation Completion', 'Extension (if any) with remarks',
#        'Time Period (in days)', 'Status', 'Master', 'Chief Engineer',
#        'Superintendent', 'Details of potential loss Category',
#        'Date of Near Miss', 'PIC', 'Port Name', 'Related Department',
#        'Description of event leading to the incident',
#        'Immediate action taken', 'Potential extent of damage/injury',
#        'Potential Damage category', 'Potential Damage subcategory',
#        'Immediate action initiated', 'Learning Potential',
#        'Severity of incident', 'External authority reporting required',
#        'Further Investigation Required', 'Corrective Action',
#        'Incident communicated to oil majors',
#        'Potential incident to be shared with industry', 'Due Date',
#        'Status of CA', 'Closure Date - CA', 'Remarks - CA', 'Report Type',
#        'DirectCause', 'IndirectCause', 'RootCause', 'RevisedIncidentCategory',
#        'LessionLearnt', 'ReviewComments', 'ClosingNote', 'ClosingDate',
#        'Incident_Category_Potential', 'Probability_of_Reoccurence',
#        'Port Country Name'],
#       dtype='str')

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12446 entries, 0 to 12445
# Data columns (total 57 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   NME ID                                          12446 non-null  str
#  1   Ref.No.                                         12445 non-null  str
#  2   Name of Ship                                    12446 non-null  str
#  3   Type of Ship                                    12446 non-null  str
#  4   Date of Report                                  11787 non-null  str
#  5   Delay (in days)                                 1251 non-null   float64
#  6   Description of the incident and cause analysis  12344 non-null  str
#  7   Location                                        11773 non-null  str
#  8   Probability of Reoccurence                      11583 non-null  str
#  9   Cause Analysis                                  4936 non-null   str
#  10  Counter measure to prevent recurrence           1903 non-null   str
#  11  Suggested Corrective Action (Office Use)        11085 non-null  str
#  12  Date Corrective action completed                1065 non-null   str
#  13  Area of Concern                                 9388 non-null   str
#  14  Date Investigation Commenced                    983 non-null    str
#  15  Target Date                                     1222 non-null   str
#  16  Date of Investigation Completion                1089 non-null   str
#  17  Extension (if any) with remarks                 44 non-null     str
#  18  Time Period (in days)                           338 non-null    float64
#  19  Status                                          11795 non-null  str
#  20  Master                                          1088 non-null   str
#  21  Chief Engineer                                  1040 non-null   str
#  22  Superintendent                                  1174 non-null   str
#  23  Details of potential loss Category              4816 non-null   str
#  24  Date of Near Miss                               12444 non-null  str
#  25  PIC                                             257 non-null    str
#  26  Port Name                                       3020 non-null   str
#  27  Related Department                              3928 non-null   str
#  28  Description of event leading to the incident    7619 non-null   str
#  29  Immediate action taken                          9758 non-null   str
#  30  Potential extent of damage/injury               7383 non-null   str
#  31  Potential Damage category                       3320 non-null   str
#  32  Potential Damage subcategory                    3320 non-null   str
#  33  Immediate action initiated                      3029 non-null   str
#  34  Learning Potential                              7539 non-null   str
#  35  Severity of incident                            8316 non-null   str
#  36  External authority reporting required           3320 non-null   str
#  37  Further Investigation Required                  3320 non-null   str
#  38  Corrective Action                               2812 non-null   str
#  39  Incident communicated to oil majors             3320 non-null   str
#  40  Potential incident to be shared with industry   3320 non-null   str
#  41  Due Date                                        257 non-null    str
#  42  Status of CA                                    257 non-null    str
#  43  Closure Date - CA                               255 non-null    str
#  44  Remarks - CA                                    256 non-null    str
#  45  Report Type                                     608 non-null    str
#  46  DirectCause                                     5331 non-null   str
#  47  IndirectCause                                   86 non-null     str
#  48  RootCause                                       105 non-null    str
#  49  RevisedIncidentCategory                         262 non-null    str
#  50  LessionLearnt                                   1691 non-null   str
#  51  ReviewComments                                  1528 non-null   str
#  52  ClosingNote                                     5933 non-null   str
#  53  ClosingDate                                     5362 non-null   str
#  54  Incident_Category_Potential                     12446 non-null  str
#  55  Probability_of_Reoccurence                      12446 non-null  str
#  56  Port Country Name                               414 non-null    str
# dtypes: float64(2), str(55)
# memory usage: 5.4 MB

# %%
data['Area of Concern'].isnull().sum()
# Out:
# np.int64(3058)

# %%
data['Area of Concern'].value_counts()
# Out:
# Area of Concern
# Safety Management                4112
# Engine & Steering Compartment    1216
# Mooring                          1052
# Cargo And Ballast System          802
# Navigation                        523
# General App & Condition           484
# Others                            453
# Cowsp                             212
# Crew Management                   172
# Environment                       129
# Company Documents                  87
# Communication                      75
# Planned Maintenance                25
# Monitoring                         23
# Execution & Monitoring             13
# Lack Of Procedure                   6
# Annexure 1 To Annexure 6            4
# Name: count, dtype: int64

# %%
data['Cause Analysis'].isna().sum()
# Out:
# np.int64(7510)

# %%
data['Chief Engineer'].value_counts()
# Out:
# Chief Engineer
# C/E.SelvaKumar                 46
# PRS Nair                       31
# Molano Alan                    26
# Jiby Joseph                    24
# Thirunavkkarasu chezhain       24
#                                ..
# Ruhul rai                       1
# Rahul                           1
# Mr James Martin                 1
# Gulshan Singh Ramkala Singh     1
# Felix B. Climaco                1
# Name: count, Length: 300, dtype: int64

# %%
data['Chief Engineer'].isna().sum()
# Out:
# np.int64(11406)

# %%
data['ClosingDate'].isna().sum()
# Out:
# np.int64(7084)

# %%
data['ClosingNote'].isna().sum()
# Out:
# np.int64(6513)

# %%
data['Closure Date - CA'].isna().sum()
# Out:
# np.int64(12191)

# %%
data.drop(columns=['Closure Date - CA'], inplace=True)

# %%
data['Corrective Action'].isna().sum()
# Out:
# np.int64(9634)

# %%
data.drop(columns=['Corrective Action'], inplace=True)

# %%
data.columns
# Out:
# Index(['NME ID', 'Ref.No.', 'Name of Ship', 'Type of Ship', 'Date of Report',
#        'Delay (in days)', 'Description of the incident and cause analysis',
#        'Location', 'Probability of Reoccurence', 'Cause Analysis',
#        'Counter measure to prevent recurrence',
#        'Suggested Corrective Action (Office Use)',
#        'Date Corrective action completed', 'Area of Concern',
#        'Date Investigation Commenced', 'Target Date',
#        'Date of Investigation Completion', 'Extension (if any) with remarks',
#        'Time Period (in days)', 'Status', 'Master', 'Chief Engineer',
#        'Superintendent', 'Details of potential loss Category',
#        'Date of Near Miss', 'PIC', 'Port Name', 'Related Department',
#        'Description of event leading to the incident',
#        'Immediate action taken', 'Potential extent of damage/injury',
#        'Potential Damage category', 'Potential Damage subcategory',
#        'Immediate action initiated', 'Learning Potential',
#        'Severity of incident', 'External authority reporting required',
#        'Further Investigation Required', 'Incident communicated to oil majors',
#        'Potential incident to be shared with industry', 'Due Date',
#        'Status of CA', 'Remarks - CA', 'Report Type', 'DirectCause',
#        'IndirectCause', 'RootCause', 'RevisedIncidentCategory',
#        'LessionLearnt', 'ReviewComments', 'ClosingNote', 'ClosingDate',
#        'Incident_Category_Potential', 'Probability_of_Reoccurence',
#        'Port Country Name'],
#       dtype='str')

# %%
data['Counter measure to prevent recurrence'].value_counts()
# Out:
# Counter measure to prevent recurrence
# 1. The above mentioned near miss report was discussed with all the crew. The causes that lead to such a near miss were clearly explained.    2
# The above scenario was discussed with all the crew member. Everyone understood the importance of wearing the PPE/Safety gears.               2
# Proper recording of data should be carefully studied before entries are to be made into the appropriate record book                          2
# Wind conditions shall be considered  during flag hoisting, if required additional person shall be used for hoisting.                         2
# WINDLASS HYDRAULIC MOTOR TO BE OVERHAULED AND SAME ADDED IN DRY DOCK SPECS.                                                                  2
#                                                                                                                                             ..
# Proper PPE to be worn at all times when working on deck.                                                                                     1
# DISCUSSION WITH THE COMPANY TO PROVIDE SUFFICIENT DECK HANDS TO CARRY OUT SAFE SHIP BOARD OPERATIONS                                         1
# More training required as per code of safe working practices during mooring.                                                                 1
# Informed shore safety officer.                                                                                                               1
# Training to be given to all staff about checks to be carried in lifebuoy. Regular inspection oflifebuoy to be carried out.\n                 1
# Name: count, Length: 1868, dtype: int64

# %%
data['Date Corrective action completed'].isna().sum()
# Out:
# np.int64(11381)

# %%
data['Date Investigation Commenced'].isna().sum()
# Out:
# np.int64(11463)

# %%
data['Date of Near Miss'].isna().sum()
# Out:
# np.int64(2)

# %%
data['Date of Report'].head(10)
# Out:
# 0    2012-01-03
# 1    2012-01-05
# 2    2012-01-06
# 3    2012-01-09
# 4    2012-01-23
# 5    2012-01-09
# 6    2012-01-09
# 7    2012-01-13
# 8    2012-01-11
# 9    2012-01-14
# Name: Date of Report, dtype: str

# %%
data['Delay (in days)'].isna().sum()
# Out:
# np.int64(11195)

# %%
data['Description of event leading to the incident'].isna().sum()
# Out:
# np.int64(4827)

# %%
data['Details of potential loss Category'].head(20)
# Out:
# 0     P,O,S,S,I,B,L,E, ,C,O,N,S,E,Q,U,E,N,C,E, ,(,C,...
# 1     P,O,S,S,I,B,L,E, ,C,O,N,S,E,Q,U,E,N,C,E, ,(,C,...
# 2     P,O,S,S,I,B,L,E, ,C,O,N,S,E,Q,U,E,N,C,E, ,(,C,...
# 3     P,O,S,S,I,B,L,E, ,C,O,N,S,E,Q,U,E,N,C,E, ,(,C,...
# 4     P,O,S,S,I,B,L,E, ,C,O,N,S,E,Q,U,E,N,C,E, ,(,C,...
# 5     P,O,S,S,I,B,L,E, ,C,O,N,S,E,Q,U,E,N,C,E, ,(,C,...
# 6     P,O,S,S,I,B,L,E, ,C,O,N,S,E,Q,U,E,N,C,E, ,(,C,...
# 7     P,O,S,S,I,B,L,E, ,C,O,N,S,E,Q,U,E,N,C,E, ,(,C,...
# 8     P,O,S,S,I,B,L,E, ,C,O,N,S,E,Q,U,E,N,C,E, ,(,C,...
# 9     P,O,S,S,I,B,L,E, ,C,O,N,S,E,Q,U,E,N,C,E, ,(,C,...
# 10    P,O,S,S,I,B,L,E, ,C,O,N,S,E,Q,U,E,N,C,E, ,(,C,...
# 11    P,O,S,S,I,B,L,E, ,C,O,N,S,E,Q,U,E,N,C,E, ,(,C,...
# 12    P,O,S,S,I,B,L,E, ,C,O,N,S,E,Q,U,E,N,C,E, ,(,C,...
# 13    P,O,S,S,I,B,L,E, ,C,O,N,S,E,Q,U,E,N,C,E, ,(,C,...
# 14    P,O,S,S,I,B,L,E, ,C,O,N,S,E,Q,U,E,N,C,E, ,(,C,...
# 15    P,O,S,S,I,B,L,E, ,C,O,N,S,E,Q,U,E,N,C,E, ,(,C,...
# 16    P,O,S,S,I,B,L,E, ,C,O,N,S,E,Q,U,E,N,C,E, ,(,C,...
# 17    P,O,S,S,I,B,L,E, ,C,O,N,S,E,Q,U,E,N,C,E, ,(,C,...
# 18    P,O,S,S,I,B,L,E, ,C,O,N,S,E,Q,U,E,N,C,E, ,(,C,...
# 19    P,O,S,S,I,B,L,E, ,C,O,N,S,E,Q,U,E,N,C,E, ,(,C,...
# Name: Details of potential loss Category, dtype: str

# %%
data['Details of potential loss Category'].isna().sum()
# Out:
# np.int64(7630)

# %%
data['Details of potential loss Category'].value_counts()
# Out:
# Details of potential loss Category
# Personal Injury                                                                                                                                                                                                                                                363
# Man Hour Lost ,Personal Injury                                                                                                                                                                                                                                 164
# 2) Personal Injury                                                                                                                                                                                                                                             152
# Man Hour Lost                                                                                                                                                                                                                                                  148
# Fatality / Disability                                                                                                                                                                                                                                          108
#                                                                                                                                                                                                                                                               ...
# Personal Injury ,Time Delay To The Vessel ,Own Vessel Machinery Damage ,Fatality / Disability ,Man Hour Lost                                                                                                                                                     1
# Own Vessel-Other Property Damage ,Partial Damage ,Time Delay To The Vessel                                                                                                                                                                                       1
# Own Vessel Hull Damage ,Own Vessel Machinery Damage ,Third Party Damage (Other Vessel,Floating Objects,Shore Structure & Cargo Ashore Or On Other Ship) ,Time Delay To The Vessel                                                                                1
# Own Vessel Machinery Damage ,Own Vessel-Other Property Damage ,Life At Stake(In Emergency) If Life Boat Is Out Of Sevice.                                                                                                                                        1
# Commercial Loss (Loss Of Hire) ,Environmental Damage ,Man Hour Lost ,Own Vessel Hull Damage ,Reputation Loss / Media Exposure ,Third Party Damage (Other Vessel,Floating Objects,Shore Structure & Cargo Ashore Or On Other Ship) ,Time Delay To The Vessel      1
# Name: count, Length: 2451, dtype: int64

# %%
data['DirectCause'].head(20)
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# Name: DirectCause, dtype: str

# %%
data['Due Date'].isna().sum()
# Out:
# np.int64(12189)

# %%
data['Extension (if any) with remarks'].isna().sum()
# Out:
# np.int64(12402)

# %%
data['External authority reporting required'].isna().sum()
# Out:
# np.int64(9126)

# %%
data['Further Investigation Required'].isna().sum()
# Out:
# np.int64(9126)

# %%
data['Immediate action initiated'].isna().sum()
# Out:
# np.int64(9417)

# %%
data['Incident communicated to oil majors'].isna().sum()
# Out:
# np.int64(9126)

# %%
data['Incident_Category_Potential'].head(20)
# Out:
# 0     Marginal-Moderate-Medium
# 1              Critical-Severe
# 2     Marginal-Moderate-Medium
# 3             Minor-Low-Slight
# 4             Minor-Low-Slight
# 5     Marginal-Moderate-Medium
# 6             Minor-Low-Slight
# 7              Critical-Severe
# 8     Marginal-Moderate-Medium
# 9             Minor-Low-Slight
# 10    Marginal-Moderate-Medium
# 11    Marginal-Moderate-Medium
# 12    Marginal-Moderate-Medium
# 13    Marginal-Moderate-Medium
# 14    Marginal-Moderate-Medium
# 15    Marginal-Moderate-Medium
# 16            Minor-Low-Slight
# 17    Marginal-Moderate-Medium
# 18            Minor-Low-Slight
# 19    Marginal-Moderate-Medium
# Name: Incident_Category_Potential, dtype: str

# %%
data['Learning Potential']
# Out:
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
#           ...
# 12441       Low
# 12442       NaN
# 12443       NaN
# 12444    Medium
# 12445    Medium
# Name: Learning Potential, Length: 12446, dtype: str

# %%
data['Learning Potential'].isna().sum()
# Out:
# np.int64(4907)

# %%
data['Learning Potential'].value_counts()
# Out:
# Learning Potential
# Low       5488
# Medium    1941
# High       110
# Name: count, dtype: int64

# %%
data['IndirectCause'].isna().sum()
# Out:
# np.int64(12360)

# %%
data['Suggested Corrective Action (Office Use)'].value_counts()
# Out:
# Suggested Corrective Action (Office Use)
# NIL                                                                                                                                                                                                                                                                                                                                                 318
# Review pending                                                                                                                                                                                                                                                                                                                                       59
# Review Pending                                                                                                                                                                                                                                                                                                                                       39
# review pending                                                                                                                                                                                                                                                                                                                                       19
# Pending                                                                                                                                                                                                                                                                                                                                              14
#                                                                                                                                                                                                                                                                                                                                                    ...
# Safe operation procedure of the deck machinery to be discussed with the foreman or stevedoring supervisor.   Maintain proper deck watch keeping: Deck watch and duty officer must be fully aware of all operation going on at all times.                                                                                                              1
# review safety working practice when the ship sailing on hard sea.                                                                                                                                                                                                                                                                                     1
# All engine staff were briefed regarding the consequence of exposed high flammable items near to a heat source. A sink with metal lid for storing the used oil/ solvents for filter cleaning has been deginated in the purifier room which is covered and away from vicinity of any heat source. So, there will not be any potential fire hazard.      1
# The OOW to be alert at all times and should be in line of sight of the tug personnel to attract the attention incase needed.OOW to be in close communication with the bridge at all times.                                                                                                                                                            1
# Hoses to be replaced on periodic basis depending on makers instruction.                                                                                                                                                                                                                                                                               1
# Name: count, Length: 9033, dtype: int64

# %%
data['LessionLearnt'].isna().sum()
# Out:
# np.int64(10755)

# %%
data['Location'].value_counts()
# Out:
# Location
# Sea               6884
# Port              3024
# On Deck            791
# Machinery Room     383
# Mooring Area       165
# Bridge             164
# Accommodation      136
# Others              65
# Galley              56
# Cargo Hold          48
# Ballast Tank        34
# Pump Room           17
# Engine Room          6
# Name: count, dtype: int64

# %%
data['Master'].value_counts()
# Out:
# Master
# Capt.AYYAGARI \nRAVISHANKAR    46
# Rajasekar                      28
# Pollentes Luis Rey             24
# Senthil kumar                  24
# Praveen Jaiswal                16
#                                ..
# Capt. Raj Srivastava            1
# Capt. F Moraes                  1
# Musharraf Iqbal                 1
# Baljeet                         1
# Jeremias L. Laranjo             1
# Name: count, Length: 343, dtype: int64

# %%
data['NME ID'].value_counts()
# Out:
# NME ID
# NME100000    1
# NME100001    1
# NME100002    1
# NME100003    1
# NME100004    1
#             ..
# NME112441    1
# NME112442    1
# NME112443    1
# NME112444    1
# NME112445    1
# Name: count, Length: 12446, dtype: int64

# %%
data['Name of Ship'].value_counts()
# Out:
# Name of Ship
# KM HAKATA          213
# FUJI GAS           196
# TIRUMALA GAS       173
# SABARIMALA GAS     169
# NANYANG STAR       152
#                   ...
# VIETNAM EXPRESS      1
# LOWLANDS DAWN        1
# LOWLANDS FUTURE      1
# VIALLI               1
# MENTOR               1
# Name: count, Length: 357, dtype: int64

# %%
data['PIC'].value_counts()
# Out:
# PIC
# Master                   115
# Chief Officer             70
# Chief Engineer            39
# Ravi kumar.K              10
# Second Engineer            5
# Sachin Bagga               3
# Satheesh Chinnadurai       3
# Daniel C                   3
# Arputharaj                 2
# Naveen Kumar               1
# Duraisamy Natarajan        1
# Abhishek Kumar             1
# Electricalofficer          1
# Khalid Nawaz               1
# Second Officer             1
# Harris Surendar Moses      1
# Name: count, dtype: int64

# %%
data['Port Country Name'].isna().sum()
# Out:
# np.int64(12032)

# %%
data['Port Name'].value_counts()
# Out:
# Port Name
# SINGAPORE                           143
# FUJAIRAH                             75
# HOUSTON                              53
# MUMBAI                               46
# ROTTERDAM                            42
#                                    ...
# DONGGUAN                              1
# HODEIDAH                              1
# AUGHINISH ISLAND MARINE TERMINAL      1
# ODENSE                                1
# WADI FEIRAN                           1
# Name: count, Length: 671, dtype: int64

# %%
data['Potential Damage category'].isna().sum()
# Out:
# np.int64(9126)

# %%
data['Potential Damage subcategory'].isna().sum()
# Out:
# np.int64(9126)

# %%
data['Potential extent of damage/injury'].isna().sum()
# Out:
# np.int64(5063)

# %%
data['Potential extent of damage/injury'].value_counts()
# Out:
# Potential extent of damage/injury
# NIL                                                                                                                              115
# Nil                                                                                                                               94
# NONE                                                                                                                              93
# Personal Injury                                                                                                                   72
# none                                                                                                                              52
#                                                                                                                                 ...
# Caused injury to his foot seriously                                                                                                1
# Loss of steering may lead to collision / allision /grounding /injury to personnel/ damage to vessel, cargo and environment.        1
# The said nearmiss could potentialy cause severe damage to the deck machinery, indury to personnel and delay to the operation.      1
# Potential personal injury leading to first aid case.                                                                               1
# Could have resulted in injury to crew.                                                                                             1
# Name: count, Length: 5036, dtype: int64

# %%
data['Potential incident to be shared with industry'].isna().sum()
# Out:
# np.int64(9126)

# %%
data['Probability of Reoccurence'].isna().sum()
# Out:
# np.int64(863)

# %%
data['Probability of Reoccurence'].value_counts()
# Out:
# Probability of Reoccurence
# Unlikely                                                                                        4279
# Likely                                                                                          3927
# Very Unlikely                                                                                   1463
# Very Likely                                                                                      866
# Low                                                                                              297
# 3) Unlikely                                                                                      260
# 2) Likely                                                                                        214
# 1) Very Unlikely                                                                                 117
# Medium                                                                                            47
# Very Low                                                                                          40
# 4) Very Likely                                                                                    37
# High                                                                                              15
# Moderate                                                                                          13
# Marginal                                                                                           2
# Very High                                                                                          1
# Commercial Loss / Reputation Loss                                                                  1
# Minor                                                                                              1
# Critical / Severe Harm                                                                             1
# Na                                                                                                 1
# Ch V/Safety Management- (Reporting- Larp, Near Misses, Incident Investigations And Psc Etc.)       1
# Name: count, dtype: int64

# %%
data['Probability_of_Reoccurence'].value_counts()
# Out:
# Probability_of_Reoccurence
# Unlikely-Low-Marginal          4578
# Likely-High-Medium-Moderate    4002
# Very Unlikely-Very Low         1503
# Others                         1496
# Very Likely-Very High           867
# Name: count, dtype: int64

# %%
data['Ref.No.'].value_counts()
# Out:
# Ref.No.
# CAL-01/2012           1
# CHI-01/2012           1
# CHI-02/2012           1
# FLD-01-2012           1
# CAP-001/12            1
#                      ..
# NM/NBAL/2020/Apr/4    1
# NM/NSFX/2020/Apr/6    1
# NM/VOLN/2020/Apr/7    1
# NM/HOUM/2020/Apr/8    1
# NM/LORD/2020/May/3    1
# Name: count, Length: 12445, dtype: int64

# %%
data['Related Department'].head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# Name: Related Department, dtype: str

# %%
data['Related Department'].isna().sum()
# Out:
# np.int64(8518)

# %%
data['Remarks - CA']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 12441    NaN
# 12442    NaN
# 12443    NaN
# 12444    NaN
# 12445    NaN
# Name: Remarks - CA, Length: 12446, dtype: str

# %%
data['Remarks - CA'].isna().sum()
# Out:
# np.int64(12190)

# %%
data['Report Type'].isna().sum()
# Out:
# np.int64(11838)

# %%
data['Related Department'].isna().sum()
# Out:
# np.int64(8518)

# %%
data['ReviewComments'].isna().sum()
# Out:
# np.int64(10918)

# %%
data['RevisedIncidentCategory']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 12441    NaN
# 12442    NaN
# 12443    NaN
# 12444    NaN
# 12445    NaN
# Name: RevisedIncidentCategory, Length: 12446, dtype: str

# %%
data['RevisedIncidentCategory'].isna().sum()
# Out:
# np.int64(12184)

# %%
data['RootCause'].isna().sum()
# Out:
# np.int64(12341)

# %%
data['Severity of incident'].isna().sum()
# Out:
# np.int64(4130)

# %%
data['Severity of incident'].value_counts()
# Out:
# Severity of incident
# Low       4759
# Medium    2455
# High      1102
# Name: count, dtype: int64

# %%
data['Status'].value_counts()
# Out:
# Status
# Closed          9766
# Open             943
# Invalid          634
# Under Review     452
# Name: count, dtype: int64

# %%
data['Status of CA'].isna().sum()
# Out:
# np.int64(12189)

# %%
data['Superintendent'].isna().sum()
# Out:
# np.int64(11272)

# %%
data['Target Date'].isna().sum()
# Out:
# np.int64(11224)

# %%
data['Time Period (in days)'].value_counts()
# Out:
# Time Period (in days)
#  2.0        15
#  1.0        15
#  4.0         9
#  52.0        8
#  3.0         7
#             ..
# -41655.0     1
# -41698.0     1
# -41669.0     1
# -41651.0     1
# -41687.0     1
# Name: count, Length: 149, dtype: int64

# %%
data['Time Period (in days)'].isna().sum()
# Out:
# np.int64(12108)

# %%
data['Type of Ship'].isna().sum()
# Out:
# np.int64(0)

# %%
data
# Out:
#           NME ID             Ref.No.    Name of Ship Type of Ship  \
# 0      NME100000         CAL-01/2012  APL CALIFORNIA    CONTAINER
# 1      NME100001         CHI-01/2012        TS CHINA    CONTAINER
# 2      NME100002         CHI-02/2012        TS CHINA    CONTAINER
# 3      NME100003         FLD-01-2012     APL FLORIDA    CONTAINER
# 4      NME100004          CAP-001/12   CALA PINGUINO    CONTAINER
# ...          ...                 ...             ...          ...
# 12441  NME112441  NM/NBAL/2020/Apr/4     NORD BALTIC          NAN
# 12442  NME112442  NM/NSFX/2020/Apr/6    NAVIOS FELIX          NAN
# 12443  NME112443  NM/VOLN/2020/Apr/7         VOLANTE          NAN
# 12444  NME112444  NM/HOUM/2020/Apr/8     HOURAI MARU          NAN
# 12445  NME112445  NM/LORD/2020/May/3         BW LORD          NAN
#
#                 Date of Report  Delay (in days)  \
# 0                   2012-01-03              0.0
# 1                   2012-01-05              0.0
# 2                   2012-01-06              0.0
# 3                   2012-01-09              2.0
# 4                   2012-01-23             16.0
# ...                        ...              ...
# 12441  2020-04-12 17:43:37.050              NaN
# 12442  2020-04-21 06:22:51.907              NaN
# 12443  2020-04-30 12:20:24.683              NaN
# 12444  2020-04-24 13:43:40.970              NaN
# 12445  2020-05-02 17:40:18.397              NaN
#
#           Description of the incident and cause analysis        Location  \
# 0      On 03 Jan 2012 @ 0254 hrs vessel berthed at qi...          Galley
# 1      The ship departed port of osaka ,and main engi...  Machinery Room
# 2      While the Ship was in Port ( NAGOYA - JAPAN ) ...  Machinery Room
# 3      Vessel approaching berth at Yokohama,Japan wit...          Bridge
# 4      AFT TUG LINE PARTED WHILE DEPARTING PUERTO CAB...    Mooring Area
# ...                                                  ...             ...
# 12441  Stevedores about to transfer shore escavator u...             Sea
# 12442  During Safety around checked, 4/E was focussin...             Sea
# 12443  During routine round of the engine room it was...             Sea
# 12444  While casting off the tug at aft station the t...            Port
# 12445  High pressure hydroblasting hose ruptured and ...             Sea
#
#       Probability of Reoccurence  \
# 0                         Likely
# 1                       Very Low
# 2                       Very Low
# 3                       Very Low
# 4                    Very Likely
# ...                          ...
# 12441                     Likely
# 12442                   Unlikely
# 12443                     Likely
# 12444                   Unlikely
# 12445                Very Likely
#
#                                           Cause Analysis  ... IndirectCause  \
# 0      Suspect undeclared machinery stowed inside a c...  ...           NaN
# 1      Failure to follow repair / maintenance instruc...  ...           NaN
# 2      Failure to follow repair/maintenance instructi...  ...           NaN
# 3      Prior arrival to Yokohama, vessel had very bad...  ...           NaN
# 4      Duty Officer should always check the quality o...  ...           NaN
# ...                                                  ...  ...           ...
# 12441                                                NaN  ...           NaN
# 12442                                                NaN  ...           NaN
# 12443                                                NaN  ...           NaN
# 12444                                                NaN  ...           NaN
# 12445                                                NaN  ...           NaN
#
#       RootCause RevisedIncidentCategory LessionLearnt ReviewComments  \
# 0           NaN                     NaN           NaN            NaN
# 1           NaN                     NaN           NaN            NaN
# 2           NaN                     NaN           NaN            NaN
# 3           NaN                     NaN           NaN            NaN
# 4           NaN                     NaN           NaN            NaN
# ...         ...                     ...           ...            ...
# 12441       NaN                     NaN           NaN            NaN
# 12442       NaN                     NaN           NaN            NaN
# 12443       NaN                     NaN           NaN            NaN
# 12444       NaN                     NaN           NaN            NaN
# 12445       NaN                     NaN           NaN            NaN
#
#                                              ClosingNote          ClosingDate  \
# 0                                                    NaN                  NaN
# 1                                                    NaN                  NaN
# 2                                                    NaN                  NaN
# 3                                                    NaN                  NaN
# 4                                                    NaN                  NaN
# ...                                                  ...                  ...
# 12441  Thank you for being vigilant and devoting time...  2020-04-29 00:00:00
# 12442                                                NaN                  NaN
# 12443                                                NaN                  NaN
# 12444                         UNSAFE CONDITION.NM Closed  2020-05-11 00:00:00
# 12445  High pressure hoses shall be checked thoroughl...  2020-06-01 00:00:00
#
#       Incident_Category_Potential   Probability_of_Reoccurence  \
# 0        Marginal-Moderate-Medium  Likely-High-Medium-Moderate
# 1                 Critical-Severe       Very Unlikely-Very Low
# 2        Marginal-Moderate-Medium       Very Unlikely-Very Low
# 3                Minor-Low-Slight       Very Unlikely-Very Low
# 4                Minor-Low-Slight        Very Likely-Very High
# ...                           ...                          ...
# 12441    Marginal-Moderate-Medium  Likely-High-Medium-Moderate
# 12442  Catastrophic-Major-Extreme        Unlikely-Low-Marginal
# 12443            Minor-Low-Slight  Likely-High-Medium-Moderate
# 12444            Minor-Low-Slight        Unlikely-Low-Marginal
# 12445    Marginal-Moderate-Medium        Very Likely-Very High
#
#       Port Country Name
# 0                   NaN
# 1                   NaN
# 2                   NaN
# 3                   NaN
# 4                   NaN
# ...                 ...
# 12441               NaN
# 12442               NaN
# 12443               NaN
# 12444               NaN
# 12445               NaN
#
# [12446 rows x 55 columns]

# %%
data.shape
data.columns
data.info()
data.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12446 entries, 0 to 12445
# Data columns (total 55 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   NME ID                                          12446 non-null  str
#  1   Ref.No.                                         12445 non-null  str
#  2   Name of Ship                                    12446 non-null  str
#  3   Type of Ship                                    12446 non-null  str
#  4   Date of Report                                  11787 non-null  str
#  5   Delay (in days)                                 1251 non-null   float64
#  6   Description of the incident and cause analysis  12344 non-null  str
#  7   Location                                        11773 non-null  str
#  8   Probability of Reoccurence                      11583 non-null  str
#  9   Cause Analysis                                  4936 non-null   str
#  10  Counter measure to prevent recurrence           1903 non-null   str
#  11  Suggested Corrective Action (Office Use)        11085 non-null  str
#  12  Date Corrective action completed                1065 non-null   str
#  13  Area of Concern                                 9388 non-null   str
#  14  Date Investigation Commenced                    983 non-null    str
#  15  Target Date                                     1222 non-null   str
#  16  Date of Investigation Completion                1089 non-null   str
#  17  Extension (if any) with remarks                 44 non-null     str
#  18  Time Period (in days)                           338 non-null    float64
#  19  Status                                          11795 non-null  str
#  20  Master                                          1088 non-null   str
#  21  Chief Engineer                                  1040 non-null   str
#  22  Superintendent                                  1174 non-null   str
#  23  Details of potential loss Category              4816 non-null   str
#  24  Date of Near Miss                               12444 non-null  str
#  25  PIC                                             257 non-null    str
#  26  Port Name                                       3020 non-null   str
#  27  Related Department                              3928 non-null   str
#  28  Description of event leading to the incident    7619 non-null   str
#  29  Immediate action taken                          9758 non-null   str
#  30  Potential extent of damage/injury               7383 non-null   str
#  31  Potential Damage category                       3320 non-null   str
#  32  Potential Damage subcategory                    3320 non-null   str
#  33  Immediate action initiated                      3029 non-null   str
#  34  Learning Potential                              7539 non-null   str
#  35  Severity of incident                            8316 non-null   str
#  36  External authority reporting required           3320 non-null   str
#  37  Further Investigation Required                  3320 non-null   str
#  38  Incident communicated to oil majors             3320 non-null   str
#  39  Potential incident to be shared with industry   3320 non-null   str
#  40  Due Date                                        257 non-null    str
#  41  Status of CA                                    257 non-null    str
#  42  Remarks - CA                                    256 non-null    str
#  43  Report Type                                     608 non-null    str
#  44  DirectCause                                     5331 non-null   str
#  45  IndirectCause                                   86 non-null     str
#  46  RootCause                                       105 non-null    str
#  47  RevisedIncidentCategory                         262 non-null    str
#  48  LessionLearnt                                   1691 non-null   str
#  49  ReviewComments                                  1528 non-null   str
#  50  ClosingNote                                     5933 non-null   str
#  51  ClosingDate                                     5362 non-null   str
#  52  Incident_Category_Potential                     12446 non-null  str
#  53  Probability_of_Reoccurence                      12446 non-null  str
#  54  Port Country Name                               414 non-null    str
# dtypes: float64(2), str(53)
# memory usage: 5.2 MB
#        Delay (in days)  Time Period (in days)
# count      1251.000000             338.000000
# mean          4.031175           -6237.183432
# std        1662.269228           14931.322805
# min      -41501.000000          -41698.000000
# 25%           0.000000               2.000000
# 50%           1.000000              21.000000
# 75%           3.000000              57.250000
# max       41610.000000             195.000000

# %%
date_cols = [
    'Date of Report', 'Date Corrective action completed',
    'Date Investigation Commenced', 'Target Date',
    'Date of Investigation Completion', 'Date of Near Miss',
    'ClosingDate'
]

for col in date_cols:
    data[col] = pd.to_datetime(data[col], errors='coerce')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2080\967419297.py:9: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data[col] = pd.to_datetime(data[col], errors='coerce')

# %%
missing = data.isnull().sum().sort_values(ascending=False)
missing_percent = (missing / len(data)) * 100

missing_df = pd.DataFrame({
    "Missing Count": missing,
    "Missing %": missing_percent
})

missing_df.head(20)
# Out:
#                                   Missing Count  Missing %
# Extension (if any) with remarks           12402  99.646473
# IndirectCause                             12360  99.309015
# RootCause                                 12341  99.156355
# Remarks - CA                              12190  97.943114
# PIC                                       12189  97.935080
# Status of CA                              12189  97.935080
# Due Date                                  12189  97.935080
# RevisedIncidentCategory                   12184  97.894906
# Time Period (in days)                     12108  97.284268
# Port Country Name                         12032  96.673630
# Report Type                               11838  95.114896
# Date Investigation Commenced              11471  92.166158
# Chief Engineer                            11406  91.643902
# Date Corrective action completed          11401  91.603728
# Date of Investigation Completion          11366  91.322513
# Master                                    11358  91.258236
# Superintendent                            11272  90.567251
# Target Date                               11233  90.253897
# Delay (in days)                           11195  89.948578
# Date of Report                            11175  89.787884

# %%
drop_cols = [
    'Extension (if any) with remarks',
    'IndirectCause',
    'RootCause',
    'Remarks - CA',
    'PIC',
    'Status of CA',
    'Due Date',
    'RevisedIncidentCategory',
    'Time Period (in days)',
    'Port Country Name',
    'Report Type',
    'Date Investigation Commenced',
    'Chief Engineer',
    'Date Corrective action completed',
    'Date of Investigation Completion',
    'Master',
    'Superintendent',
    'Target Date'
]

data = data.drop(columns=drop_cols)

# %%
data = data.dropna(subset=['Delay (in days)'])

# %%
data['Type of Ship'].value_counts().head(10)
# Out:
# Type of Ship
# TANKER          474
# CONTAINER       310
# BULK CARRIER    297
# OIL TANKER      146
# LPG CARRIER      22
# NAN               2
# Name: count, dtype: int64

# %%
data['Type of Ship'].value_counts().head(10)
# Out:
# Type of Ship
# TANKER          474
# CONTAINER       310
# BULK CARRIER    297
# OIL TANKER      146
# LPG CARRIER      22
# NAN               2
# Name: count, dtype: int64

# %%
data['Delay (in days)'].describe()
# Out:
# count     1251.000000
# mean         4.031175
# std       1662.269228
# min     -41501.000000
# 25%          0.000000
# 50%          1.000000
# 75%          3.000000
# max      41610.000000
# Name: Delay (in days), dtype: float64

# %%
import matplotlib.pyplot as plt

data['Delay (in days)'].hist(bins=50)
plt.show()

# %%
data = data[
    (data['Delay (in days)'] >= 0) &
    (data['Delay (in days)'] <= 30)
]

# %%
Q1 = data['Delay (in days)'].quantile(0.25)
Q3 = data['Delay (in days)'].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

data = data[
    (data['Delay (in days)'] >= lower) &
    (data['Delay (in days)'] <= upper)
]

# %%
data['Delay (in days)'].describe()
# Out:
# count    1040.000000
# mean        0.808654
# std         1.245172
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         5.000000
# Name: Delay (in days), dtype: float64

# %%
data['Delay (in days)'].value_counts().head(10)
# Out:
# Delay (in days)
# 0.0    599
# 1.0    247
# 2.0     82
# 4.0     44
# 3.0     43
# 5.0     25
# Name: count, dtype: int64

# %%
data[['Severity of incident', 'Delay (in days)']].head()
# Out:
#   Severity of incident  Delay (in days)
# 0                  NaN              0.0
# 1                  NaN              0.0
# 2                  NaN              0.0
# 3                  NaN              2.0
# 5                  NaN              1.0

# %%
data[['Severity of incident', 'Delay (in days)']].isnull().sum()
# Out:
# Severity of incident    1040
# Delay (in days)            0
# dtype: int64

# %%
clean_box = data.dropna(subset=['Severity of incident', 'Delay (in days)'])

# %%
clean_box = clean_box[
    (clean_box['Delay (in days)'] >= 0) &
    (clean_box['Delay (in days)'] <= 30)
]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.boxplot(x='Severity of incident', y='Delay (in days)', data=clean_box)
plt.xticks(rotation=45)
plt.show()

# %%
clean_box.shape
clean_box['Severity of incident'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
clean_box['Severity of incident'] = clean_box['Severity of incident'].astype(str)

# %%
clean_box['Severity of incident'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
delay_df = data[data['Delay (in days)'].notna()]

# %%
delay_df = delay_df[
    (delay_df['Delay (in days)'] >= 0) &
    (delay_df['Delay (in days)'] <= 100)
]

# %%
delay_df.shape
# Out:
# (1040, 37)

# %%
delay_df['Severity of incident'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
delay_df['Delay (in days)'].describe()
# Out:
# count    1040.000000
# mean        0.808654
# std         1.245172
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         5.000000
# Name: Delay (in days), dtype: float64

# %%
data['Severity of incident'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
combined = data.dropna(subset=['Delay (in days)', 'Severity of incident'])
combined.shape
# Out:
# (0, 37)

# %%
data = data.loc[:, data.isnull().mean() < 0.7]

# %%
data.columns.tolist()
# Out:
# ['NME ID',
#  'Ref.No.',
#  'Name of Ship',
#  'Type of Ship',
#  'Date of Report',
#  'Delay (in days)',
#  'Description of the incident and cause analysis',
#  'Location',
#  'Probability of Reoccurence',
#  'Cause Analysis',
#  'Counter measure to prevent recurrence',
#  'Suggested Corrective Action (Office Use)',
#  'Area of Concern',
#  'Status',
#  'Details of potential loss Category',
#  'Date of Near Miss',
#  'Incident_Category_Potential',
#  'Probability_of_Reoccurence']

# %%
[['Delay', 'Time Period']]
# Out:
# [['Delay', 'Time Period']]

# %%
num_df = data.select_dtypes(include=['float64', 'int64'])

num_df = num_df.dropna()

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6,4))
sns.heatmap(num_df.corr(), annot=True)
plt.show()

# %%
data.columns
# Out:
# Index(['NME ID', 'Ref.No.', 'Name of Ship', 'Type of Ship', 'Date of Report',
#        'Delay (in days)', 'Description of the incident and cause analysis',
#        'Location', 'Probability of Reoccurence', 'Cause Analysis',
#        'Counter measure to prevent recurrence',
#        'Suggested Corrective Action (Office Use)', 'Area of Concern', 'Status',
#        'Details of potential loss Category', 'Date of Near Miss',
#        'Incident_Category_Potential', 'Probability_of_Reoccurence'],
#       dtype='str')

# %%
data.columns = data.columns.str.strip()  # remove spaces

data = data.rename(columns={
    'Ref.No.': 'ref_no',
    'Name of Ship': 'ship_name',
    'Type of Ship': 'ship_type',
    'Date of Report': 'report_date',
    'Delay (in days)': 'delay_days',
    'Description of the incident and cause analysis': 'description',
    'Probability of Reoccurence': 'probability',
    'Probability_of_Reoccurence': 'probability_dup',
    'Cause Analysis': 'cause_analysis',
    'Counter measure to prevent recurrence': 'counter_measure',
    'Suggested Corrective Action (Office Use)': 'corrective_action',
    'Area of Concern': 'area',
    'Details of potential loss Category': 'loss_category',
    'Date of Near Miss': 'near_miss_date',
    'Incident_Category_Potential': 'incident_category'
})

# %%
data.columns
# Out:
# Index(['NME ID', 'ref_no', 'ship_name', 'ship_type', 'report_date',
#        'delay_days', 'description', 'Location', 'probability',
#        'cause_analysis', 'counter_measure', 'corrective_action', 'area',
#        'Status', 'loss_category', 'near_miss_date', 'incident_category',
#        'probability_dup'],
#       dtype='str')

# %%
(data['probability'] == data['probability_dup']).sum()
# Out:
# np.int64(0)

# %%
data.info()
data.isnull().sum()
# Out:
# <class 'pandas.DataFrame'>
# Index: 1040 entries, 0 to 1296
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   NME ID             1040 non-null   str
#  1   ref_no             1039 non-null   str
#  2   ship_name          1040 non-null   str
#  3   ship_type          1040 non-null   str
#  4   report_date        1039 non-null   datetime64[us]
#  5   delay_days         1040 non-null   float64
#  6   description        1030 non-null   str
#  7   Location           1017 non-null   str
#  8   probability        865 non-null    str
#  9   cause_analysis     1026 non-null   str
#  10  counter_measure    1027 non-null   str
#  11  corrective_action  1039 non-null   str
#  12  area               658 non-null    str
#  13  Status             1039 non-null   str
#  14  loss_category      1040 non-null   str
#  15  near_miss_date     1039 non-null   datetime64[us]
#  16  incident_category  1040 non-null   str
#  17  probability_dup    1040 non-null   str
# dtypes: datetime64[us](2), float64(1), str(15)
# memory usage: 154.4 KB
# NME ID                 0
# ref_no                 1
# ship_name              0
# ship_type              0
# report_date            1
# delay_days             0
# description           10
# Location              23
# probability          175
# cause_analysis        14
# counter_measure       13
# corrective_action      1
# area                 382
# Status                 1
# loss_category          0
# near_miss_date         1
# incident_category      0
# probability_dup        0
# dtype: int64

# %%
data = data.rename(columns={
    'Location': 'location',
    'Status': 'status'
})

# %%
data['area'] = data['area'].fillna('Unknown')

# %%
data['location'] = data['location'].fillna('Unknown')
data['description'] = data['description'].fillna('No description')

# %%
data['report_year'] = data['report_date'].dt.year
data['report_month'] = data['report_date'].dt.month

data['near_miss_year'] = data['near_miss_date'].dt.year
data['near_miss_month'] = data['near_miss_date'].dt.month

# %%
data['probability'].value_counts()
# Out:
# probability
# Unlikely                             258
# Low                                  253
# Likely                               158
# Very Unlikely                         74
# Very Low                              32
# Medium                                32
# Very Likely                           30
# High                                  13
# Moderate                               9
# Marginal                               2
# Very High                              1
# Commercial Loss / Reputation Loss      1
# Minor                                  1
# Critical / Severe Harm                 1
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.hist(data['delay_days'], bins=30)
plt.title("Delay Days Distribution")
plt.show()

# %%
data[data['delay_days'] < 0]
# Out:
# Empty DataFrame
# Columns: [NME ID, ref_no, ship_name, ship_type, report_date, delay_days, description, location, probability, cause_analysis, counter_measure, corrective_action, area, status, loss_category, near_miss_date, incident_category, probability_dup, report_year, report_month, near_miss_year, near_miss_month]
# Index: []
#
# [0 rows x 22 columns]

# %%
data = data[data['delay_days'] >= 0]

# %%
data['report_year'].value_counts().sort_index()
# Out:
# report_year
# 2012.0    418
# 2013.0    621
# Name: count, dtype: int64

# %%
import seaborn as sns

sns.boxplot(x='probability', y='delay_days', data=data)
plt.show()

# %%
pd.crosstab(data['ship_type'], data['incident_category'])
# Out:
# incident_category  Catastrophic-Major-Extreme  Critical-Severe  \
# ship_type
# BULK CARRIER                                5               53
# CONTAINER                                  10               69
# LPG CARRIER                                 1                5
# NAN                                         0                0
# OIL TANKER                                  1               20
# TANKER                                     13               78
#
# incident_category  Marginal-Moderate-Medium  Minor-Low-Slight  Others
# ship_type
# BULK CARRIER                             81                46      52
# CONTAINER                                96                62      27
# LPG CARRIER                              11                 3       2
# NAN                                       0                 0       2
# OIL TANKER                               69                31      15
# TANKER                                  138                90      60

# %%
data['desc_length'] = data['description'].apply(len)

data['desc_length'].describe()
# Out:
# count    1040.000000
# mean      419.918269
# std       370.559162
# min        14.000000
# 25%       177.750000
# 50%       332.500000
# 75%       538.250000
# max      3714.000000
# Name: desc_length, dtype: float64

# %%
from collections import Counter

words = " ".join(data['description']).split()
Counter(words).most_common(20)
# Out:
# [('the', 4518),
#  ('was', 2102),
#  ('to', 2050),
#  ('and', 1842),
#  ('of', 1370),
#  ('on', 939),
#  ('in', 929),
#  ('at', 560),
#  ('that', 536),
#  ('for', 477),
#  ('from', 463),
#  ('crew', 434),
#  ('not', 425),
#  ('THE', 410),
#  ('a', 408),
#  ('were', 395),
#  ('it', 380),
#  ('with', 378),
#  ('found', 347),
#  ('vessel', 330)]
